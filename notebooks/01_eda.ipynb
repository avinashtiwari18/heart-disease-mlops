# %% [markdown]
# # Heart Disease UCI – Exploratory Data Analysis
#
# **Course:** AIMLCZG523 MLOps Assignment 01
# **Dataset:** UCI Heart Disease (Cleveland processed)
#
# This notebook covers missing-value analysis, class balance, histograms, correlation heatmaps, and feature relationships.

# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_processing import (
    FEATURE_COLUMNS,
    TARGET_COLUMN,
    clean_dataframe,
    load_raw_dataframe,
    missing_value_report,
)
from src.eda import run_eda

sns.set_theme(style="whitegrid")
print("Project root:", ROOT)

# %%
df_raw = load_raw_dataframe()
print(df_raw.shape)
df_raw.head()

# %%
missing_value_report(df_raw)

# %%
df = clean_dataframe(df_raw)
df[TARGET_COLUMN].value_counts(normalize=True)

# %%
# Generate all professional EDA plots into artifacts/eda/
out = run_eda()
list(out.glob("*.png"))

# %%
corr = df[FEATURE_COLUMNS + [TARGET_COLUMN]].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="RdBu_r", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## EDA Findings (fill after running)
#
# - Class balance is typically near-balanced for Cleveland (~46–54%).
# - Features with stronger absolute correlation to target often include `thalach`, `oldpeak`, `cp`, `exang`, and `ca`.
# - Missing values appear mainly in `ca` and `thal` in the raw Cleveland file; median imputation is applied.
