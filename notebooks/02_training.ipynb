# %% [markdown]
# # Model Development & MLflow Experiment Tracking
#
# Trains Logistic Regression, Random Forest, and XGBoost with GridSearchCV, logs metrics/artifacts to MLflow, and persists the best sklearn Pipeline.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.train import train_and_evaluate

meta = train_and_evaluate()
meta

# %%
import pandas as pd

board = pd.read_csv(ROOT / "artifacts" / "metrics" / "model_leaderboard.csv")
board.sort_values("roc_auc", ascending=False)

# %% [markdown]
# ## View MLflow UI
#
# ```bash
# mlflow ui --backend-store-uri ./mlflow_tracking --port 5000
# ```
#
# Open http://127.0.0.1:5000 to inspect parameters, metrics, ROC/confusion artifacts, and model versions.
